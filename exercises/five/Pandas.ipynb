# %%
import pandas as pd

#create a dataframe object from a csv
oscar_df = pd.read_csv('the_oscar_award.csv', delimiter=",")

oscar_df
# Out:
#        year_film  year_ceremony  ceremony                          category  \
# 0           1927           1928         1                             ACTOR
# 1           1927           1928         1                             ACTOR
# 2           1927           1928         1                           ACTRESS
# 3           1927           1928         1                           ACTRESS
# 4           1927           1928         1                           ACTRESS
# ...          ...            ...       ...                               ...
# 10390       2019           2020        92     WRITING (Original Screenplay)
# 10391       2019           2020        92  JEAN HERSHOLT HUMANITARIAN AWARD
# 10392       2019           2020        92                    HONORARY AWARD
# 10393       2019           2020        92                    HONORARY AWARD
# 10394       2019           2020        92                    HONORARY AWARD
#
# ...

# %%
oscar_df.head(10)
# Out:
#    year_film  year_ceremony  ceremony        category  \
# 0       1927           1928         1           ACTOR
# 1       1927           1928         1           ACTOR
# 2       1927           1928         1         ACTRESS
# 3       1927           1928         1         ACTRESS
# 4       1927           1928         1         ACTRESS
# 5       1927           1928         1   ART DIRECTION
# 6       1927           1928         1   ART DIRECTION
# 7       1927           1928         1   ART DIRECTION
# 8       1927           1928         1  CINEMATOGRAPHY
# 9       1927           1928         1  CINEMATOGRAPHY
#
#                       name               film  winner
# 0      Richard Barthelmess          The Noose   False
# 1            Emil Jannings   The Last Command    True
# 2           Louise Dresser    A Ship Comes In   False
# 3             Janet Gaynor         7th Heaven    True
# 4           Gloria Swanson     Sadie Thompson   False
# ...

# %%
oscar_df.sample(10)
# Out:
#        year_film  year_ceremony  ceremony                         category  \
# 8724        2006           2007        79      DOCUMENTARY (Short Subject)
# 2292        1949           1950        22       ACTOR IN A SUPPORTING ROLE
# 6329        1984           1985        57                     BEST PICTURE
# 5812        1979           1980        52                            SOUND
# 1446        1942           1943        15    WRITING (Original Screenplay)
# 10273       2019           2020        92       ACTOR IN A SUPPORTING ROLE
# 9078        2009           2010        82            FOREIGN LANGUAGE FILM
# 2309        1949           1950        22            ART DIRECTION (Color)
# 5143        1973           1974        46            FOREIGN LANGUAGE FILM
# 7618        1996           1997        69  MUSIC (Original Dramatic Score)
#
#                                                     name  \
# 8724                         Ruby Yang and Thomas Lennon
# ...

# %%
oscar_df.describe(include='all')
# Out:
#            year_film  year_ceremony      ceremony   category  \
# count   10395.000000   10395.000000  10395.000000      10395
# unique           NaN            NaN           NaN        111
# top              NaN            NaN           NaN  DIRECTING
# freq             NaN            NaN           NaN        449
# mean     1974.474555    1975.474555     47.500144        NaN
# std        26.145642      26.145642     26.102352        NaN
# min      1927.000000    1928.000000      1.000000        NaN
# 25%      1951.000000    1952.000000     24.000000        NaN
# 50%      1974.000000    1975.000000     47.000000        NaN
# 75%      1998.000000    1999.000000     71.000000        NaN
# max      2019.000000    2020.000000     92.000000        NaN
#
#                        name            film winner
# count                 10395           10091  10395
# unique                 6666            4833      2
# top     Metro-Goldwyn-Mayer  A Star Is Born  False
# ...

# %%
oscar_df['film'].value_counts()
# Out:
# A Star Is Born           25
# Titanic                  16
# Moulin Rouge             15
# Mutiny on the Bounty     15
# Little Women             14
#                          ..
# The Bolero                1
# Defending Our Lives       1
# The Good Shepherd         1
# Taxi to the Dark Side     1
# Molly's Pilgrim           1
# Name: film, Length: 4833, dtype: int64

# %%
oscar_df['name'].value_counts()[:10]
# Out:
# Metro-Goldwyn-Mayer      64
# Walt Disney, Producer    59
# John Williams            44
# Warner Bros.             43
# France                   37
# Alfred Newman            34
# Italy                    27
# Paramount                25
# RKO Radio                22
# Edith Head               22
# Name: name, dtype: int64

# %%
oscar_df['film'].value_counts()[:15].plot(kind="barh", title="Most Oscar Nominated Films")
# Out:
# <AxesSubplot:title={'center':'Most Oscar Nominated Films'}>

# %%
all_films = oscar_df['film'].unique()

for film in all_films:
    film = str(film).lower()
    if "woman" in film:
        print(film)
# Out:
# a woman of affairs;
# that hamilton woman
# this woman is mine
# the invisible woman
# woman of the year
# woman of the town
# the woman in the window
# smash-up--the story of a woman
# that forsyte woman
# designing woman
# the creation of woman
# woman in the dunes
# a man and a woman
# a woman under the influence
# antonia: a portrait of the woman
# scent of a woman
# an unmarried woman
# the french lieutenant's woman
# sewing woman
# the woman in red
# kiss of the spider woman
# pretty woman
# eat drink man woman
# the tonto woman
# a fantastic woman
